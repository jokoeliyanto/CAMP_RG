# %% [markdown]
# <a href="https://colab.research.google.com/github/jokoeliyanto/CAMP_RG/blob/main/Meet_21_Prediction_With_Python_Live_Coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction With Python Part 1

# %% [markdown]
# Dataset ini berisi harga jual rumah untuk King County, yang mencakup Seattle. Data ini termasuk data penjualan rumah antara bulan Mei 2014 dan bulan Mei 2015.

# %% [markdown]
# | Variable      | Description                                                                                                 |
# | ------------- | ----------------------------------------------------------------------------------------------------------- |
# | id            | A notation for a house                                                                                      |
# | date          | Date house was sold                                                                                         |
# | price         | Price is prediction target                                                                                  |
# | bedrooms      | Number of bedrooms                                                                                          |
# | bathrooms     | Number of bathrooms                                                                                         |
# | sqft_living   | Square footage of the home                                                                                  |
# | sqft_lot      | Square footage of the lot                                                                                   |
# | floors        | Total floors (levels) in house                                                                              |
# | waterfront    | House which has a view to a waterfront                                                                      |
# | view          | Has been viewed                                                                                             |
# | condition     | How good the condition is overall                                                                           |
# | grade         | overall grade given to the housing unit, based on King County grading system                                |
# | sqft_above    | Square footage of house apart from basement                                                                 |
# | sqft_basement | Square footage of the basement                                                                              |
# | yr_built      | Built Year                                                                                                  |
# | yr_renovated  | Year when house was renovated                                                                               |
# | zipcode       | Zip code                                                                                                    |
# | lat           | Latitude coordinate                                                                                         |
# | long          | Longitude coordinate                                                                                        |
# | sqft_living15 | Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area |
# | sqft_lot15    | LotSize area in 2015(implies-- some renovations)                                                            |

# %% [markdown]
# ## 1 Import Library

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2 Load Dataset

# %%
path_file = 'https://raw.githubusercontent.com/jokoeliyanto/CAMP_RG/main/Course_2_Meeting%20in%20class%2021-kc_house_data_NaN.csv'
df = pd.read_csv(path_file)

# %% [markdown]
# ## 3 Eksplorasi Data

# %% [markdown]
# ### Melihat Data

# %%
df.head(10)
# Out:
#    Unnamed: 0          id             date      price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000   221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000   538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000   180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000   604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000   510000.0       3.0       2.00
# 5           5  7237550310  20140512T000000  1225000.0       4.0       4.50
# 6           6  1321400060  20140627T000000   257500.0       3.0       2.25
# 7           7  2008000270  20150115T000000   291850.0       3.0       1.50
# 8           8  2414600126  20150415T000000   229500.0       3.0       1.00
# 9           9  3793500160  20150312T000000   323000.0       3.0       2.50
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0          id             date      price  bedrooms  \
# 21603       21603  7852140040  20140825T000000   507250.0       3.0
# 21604       21604  9834201367  20150126T000000   429000.0       3.0
# 21605       21605  3448900210  20141014T000000   610685.0       4.0
# 21606       21606  7936000429  20150326T000000  1007500.0       4.0
# 21607       21607  2997800021  20150219T000000   475000.0       3.0
# 21608       21608   263000018  20140521T000000   360000.0       3.0
# 21609       21609  6600060120  20150223T000000   400000.0       4.0
# 21610       21610  1523300141  20140623T000000   402101.0       2.0
# 21611       21611   291310100  20150116T000000   400000.0       3.0
# 21612       21612  1523300157  20141015T000000   325000.0       2.0
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 21603       2.50         2270      5536     2.0           0  ...      8
# 21604       2.00         1490      1126     3.0           0  ...      8
# ...

# %%
df.sample(4)
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 17837       17837  2923500750  20140718T000000  638150.0       4.0       2.50
# 13704       13704  6777800150  20140722T000000  265000.0       3.0       1.75
# 15417       15417  2929600020  20140805T000000  375000.0       3.0       1.50
# 588           588  1442740140  20140930T000000  370000.0       3.0       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 17837         2170      7275     1.0           0  ...      8        1820
# 13704         2200      7200     1.0           0  ...      8        1270
# 15417         1190     20672     1.5           0  ...      7        1190
# 588           2110     13300     2.0           0  ...      8        2110
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 17837            350      1978             0    98027  47.5672 -122.090
# ...

# %% [markdown]
# ### Dimensi Data

# %%
df.shape
# Out:
# (21613, 22)

# %% [markdown]
# ### Variabel Data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ### Informasi Lengkap Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     21613 non-null  int64
#  1   id             21613 non-null  int64
#  2   date           21613 non-null  object
#  3   price          21613 non-null  float64
#  4   bedrooms       21600 non-null  float64
#  5   bathrooms      21603 non-null  float64
#  6   sqft_living    21613 non-null  int64
#  7   sqft_lot       21613 non-null  int64
#  8   floors         21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  view           21613 non-null  int64
#  11  condition      21613 non-null  int64
#  12  grade          21613 non-null  int64
#  13  sqft_above     21613 non-null  int64
#  14  sqft_basement  21613 non-null  int64
#  15  yr_built       21613 non-null  int64
#  16  yr_renovated   21613 non-null  int64
# ...

# %% [markdown]
# ### Menghapus Kolom yang Tidak Perlu

# %%
df0 = df.copy()

# %%
df0.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df1 = df0[['price', 'bedrooms', 'bathrooms',
       'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
       'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
       'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']]

# %%
df1
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0       3.0       1.00         1180      5650     1.0
# 1      538000.0       3.0       2.25         2570      7242     2.0
# 2      180000.0       2.0       1.00          770     10000     1.0
# 3      604000.0       4.0       3.00         1960      5000     1.0
# 4      510000.0       3.0       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0       3.0       2.50         1530      1131     3.0
# 21609  400000.0       4.0       2.50         2310      5813     2.0
# 21610  402101.0       2.0       0.75         1020      1350     2.0
# 21611  400000.0       3.0       2.50         1600      2388     2.0
# 21612  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21600 non-null  float64
#  2   bathrooms      21603 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %% [markdown]
# ### Statistik Descriptive

# %%
df1.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# ### Mengecek Missing Value

# %%
df1.isnull().sum()
# Out:
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %%
df1.isnull().sum().to_frame()
# Out:
#                 0
# price           0
# bedrooms       13
# bathrooms      10
# sqft_living     0
# sqft_lot        0
# floors          0
# waterfront      0
# view            0
# condition       0
# grade           0
# sqft_above      0
# sqft_basement   0
# yr_built        0
# yr_renovated    0
# zipcode         0
# lat             0
# long            0
# sqft_living15   0
# sqft_lot15      0

# %%
sns.heatmap(df1.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %%
print("Jumlah miising data (NaN) pada kolom bedrooms :", df1['bedrooms'].isnull().sum())
print("Jumlah miising data (NaN) pada kolom bathrooms :", df1['bathrooms'].isnull().sum())
# Out:
# Jumlah miising data (NaN) pada kolom bedrooms : 13
# Jumlah miising data (NaN) pada kolom bathrooms : 10

# %% [markdown]
# ### Handling Missing Value

# %%
mean = df1['bedrooms'].mean()
df1['bedrooms'].replace(np.nan, mean, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
mean = df1['bathrooms'].mean()
df1['bathrooms'].replace(np.nan, mean, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
print("Jumlah miising data (NaN) pada kolom bedrooms :", df1['bedrooms'].isnull().sum())
print("Jumlah miising data (NaN) pada kolom bathrooms :", df1['bathrooms'].isnull().sum())
# Out:
# Jumlah miising data (NaN) pada kolom bedrooms : 0
# Jumlah miising data (NaN) pada kolom bathrooms : 0

# %%
df1.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926378      0.768818    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# ### Mengecek Outlier/Pencilan

# %%
df1=df1.select_dtypes(include=['float64', 'int64'])#Memilih kolom numerik

sns.boxplot(x="variable", y="value", color='green',orient='v', data=pd.melt(df1))
plt.tight_layout()

# %%
sns.boxplot(x="variable", y="value", color='green',orient='v', data=pd.melt(df1.iloc[:,:2]))
plt.tight_layout()

# %% [markdown]
# ### Handling Outlier

# %% [markdown]
# Rentang interkuartil (IQR) adalah ukuran penyebaran statistik dan dihitung sebagai perbedaan antara persentil ke-75 dan ke-25. Ini diwakili oleh rumus IQR = Q3 - Q1. Baris kode di bawah menghitung dan mencetak kisaran interkuartil untuk setiap variabel dalam dataset.
#
# Teknik ini menggunakan skor IQR yang dihitung sebelumnya untuk menghilangkan pencilan. Aturan praktisnya adalah bahwa segala sesuatu yang tidak berada dalam kisaran (Q1 - 1.5 IQR) dan (Q3 + 1.5 IQR) adalah pencilan, dan dapat dihapus.
#
# Metode ini dipakai karena untuk identifikasi outlier awal digunakan metode boxplot.
#
# Referensi: https://www.pluralsight.com/guides/cleaning-up-data-from-outliers

# %%
#Menghitung Skor IQR

Q1=df1.quantile(0.25)
Q3=df1.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# price            323050.000
# bedrooms              1.000
# bathrooms             0.750
# sqft_living        1123.000
# sqft_lot           5648.000
# floors                1.000
# waterfront            0.000
# view                  0.000
# condition             1.000
# grade                 1.000
# sqft_above         1020.000
# sqft_basement       560.000
# yr_built             46.000
# yr_renovated          0.000
# zipcode              85.000
# lat                   0.207
# long                  0.203
# sqft_living15       870.000
# sqft_lot15         4983.000
# dtype: float64

# %%
#Menghapus Outlier
df_clear = df1[~((df1 < (Q1 - 1.5 * IQR)) |(df1 > (Q3 + 1.5 * IQR))).any(axis=1)]
df_clear
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0       3.0       1.00         1180      5650     1.0
# 2      180000.0       2.0       1.00          770     10000     1.0
# 3      604000.0       4.0       3.00         1960      5000     1.0
# 4      510000.0       3.0       2.00         1680      8080     1.0
# 6      257500.0       3.0       2.25         1715      6819     2.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0       3.0       2.50         1530      1131     3.0
# 21609  400000.0       4.0       2.50         2310      5813     2.0
# 21610  402101.0       2.0       0.75         1020      1350     2.0
# 21611  400000.0       3.0       2.50         1600      2388     2.0
# 21612  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df_clear['waterfront'].value_counts()
# Out:
# 0    14941
# Name: waterfront, dtype: int64

# %%
df_clear
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0       3.0       1.00         1180      5650     1.0
# 2      180000.0       2.0       1.00          770     10000     1.0
# 3      604000.0       4.0       3.00         1960      5000     1.0
# 4      510000.0       3.0       2.00         1680      8080     1.0
# 6      257500.0       3.0       2.25         1715      6819     2.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0       3.0       2.50         1530      1131     3.0
# 21609  400000.0       4.0       2.50         2310      5813     2.0
# 21610  402101.0       2.0       0.75         1020      1350     2.0
# 21611  400000.0       3.0       2.50         1600      2388     2.0
# 21612  325000.0       2.0       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14941 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          14941 non-null  float64
#  1   bedrooms       14941 non-null  float64
#  2   bathrooms      14941 non-null  float64
#  3   sqft_living    14941 non-null  int64
#  4   sqft_lot       14941 non-null  int64
#  5   floors         14941 non-null  float64
#  6   waterfront     14941 non-null  int64
#  7   view           14941 non-null  int64
#  8   condition      14941 non-null  int64
#  9   grade          14941 non-null  int64
#  10  sqft_above     14941 non-null  int64
#  11  sqft_basement  14941 non-null  int64
#  12  yr_built       14941 non-null  int64
#  13  yr_renovated   14941 non-null  int64
#  14  zipcode        14941 non-null  int64
#  15  lat            14941 non-null  float64
#  16  long           14941 non-null  float64
# ...

# %% [markdown]
# ### Mengecek Korelasi

# %%
df_clear.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.239761   0.340360     0.514520 -0.085455  0.227359
# bedrooms       0.239761  1.000000   0.443726     0.614461  0.204857  0.129132
# bathrooms      0.340360  0.443726   1.000000     0.669197 -0.088659  0.524243
# sqft_living    0.514520  0.614461   0.669197     1.000000  0.164834  0.317394
# sqft_lot      -0.085455  0.204857  -0.088659     0.164834  1.000000 -0.416485
# floors         0.227359  0.129132   0.524243     0.317394 -0.416485  1.000000
# waterfront          NaN       NaN        NaN          NaN       NaN       NaN
# view                NaN       NaN        NaN          NaN       NaN       NaN
# condition      0.085225  0.029411  -0.157479    -0.068135  0.150940 -0.302414
# grade          0.527528  0.290231   0.584182     0.622674 -0.032094  0.472333
# sqft_above     0.408206  0.485781   0.592768     0.831503  0.114785  0.518445
# ...

# %%
k = len(df1.columns)
cm = df1.corr()
plt.figure(figsize=(20,15))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
df1.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308797   0.525738     0.702035  0.089661  0.256794
# bedrooms       0.308797  1.000000   0.514194     0.578077  0.032307  0.178022
# bathrooms      0.525738  0.514194   1.000000     0.755371  0.087929  0.502132
# sqft_living    0.702035  0.578077   0.755371     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032307   0.087929     0.172826  1.000000 -0.005201
# floors         0.256794  0.178022   0.502132     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080058   0.188341     0.284611  0.074710  0.029444
# condition      0.036362  0.026690  -0.126197    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356589   0.664676     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479286   0.686309     0.876597  0.183512  0.523885
# ...

# %%
df1.corr()['price']
# Out:
# price            1.000000
# bedrooms         0.308797
# bathrooms        0.525738
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %%
df1.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
df1.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525738
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308797
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
df.corr()['price'].sort_values(ascending=False).to_frame()
# Out:
#                   price
# price          1.000000
# sqft_living    0.702035
# grade          0.667434
# sqft_above     0.605567
# sqft_living15  0.585379
# bathrooms      0.525885
# view           0.397293
# sqft_basement  0.323816
# bedrooms       0.308890
# lat            0.307003
# waterfront     0.266369
# floors         0.256794
# yr_renovated   0.126434
# sqft_lot       0.089661
# sqft_lot15     0.082447
# yr_built       0.054012
# condition      0.036362
# Unnamed: 0     0.027372
# long           0.021626
# id            -0.016762
# zipcode       -0.053203

# %% [markdown]
# ## 4 Analisis Data

# %% [markdown]
# Gunakan metode value_counts untuk menghitung jumlah dari rumah yang memiliki nilai lantai yang unik, kemudian metode .to_frame() untuk mengubahnya menjadi dataframe.

# %%
df1.floors
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 21608    3.0
# 21609    2.0
# 21610    2.0
# 21611    2.0
# 21612    2.0
# Name: floors, Length: 21613, dtype: float64

# %%
df1.floors.value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %% [markdown]
# Gunakan fungsi boxplot dalam seaborn library untuk menentukan apakah rumah dengan waterfront (atau tidak memiliki waterfront) memiliki lebih banyak price outliers.

# %%
sns.boxplot(x='waterfront', y='price', data=df1)

# %% [markdown]
# Gunakan fungsi regplot pada seaborn library untuk menentukan apakah fitur sqft_above berkorelasi negatif atau positif terhadap price.

# %%
sns.regplot(x=df1["sqft_above"],y=df1["price"],data=df)
plt.ylim(0,)
# Out:
# (0.0, 8081250.0)

# %%
sns.relplot(x='price', y='sqft_above', data=df) #kita akan melakukan visualisasi terhadap data untuk melihat hubungan antara dua variabel

# %%
kolom = df1.corr()['price'].sort_values(ascending=False).to_frame().index.tolist()

# %%
kolom
# Out:
# ['price',
#  'sqft_living',
#  'grade',
#  'sqft_above',
#  'sqft_living15',
#  'bathrooms',
#  'view',
#  'sqft_basement',
#  'bedrooms',
#  'lat',
#  'waterfront',
#  'floors',
#  'yr_renovated',
#  'sqft_lot',
#  'sqft_lot15',
#  'yr_built',
#  'condition',
#  'long',
#  'zipcode']

# %%
df1_pilih = df1[kolom[:5]]
df1_pilih
# Out:
#           price  sqft_living  grade  sqft_above  sqft_living15
# 0      221900.0         1180      7        1180           1340
# 1      538000.0         2570      7        2170           1690
# 2      180000.0          770      6         770           2720
# 3      604000.0         1960      7        1050           1360
# 4      510000.0         1680      8        1680           1800
# ...         ...          ...    ...         ...            ...
# 21608  360000.0         1530      8        1530           1530
# 21609  400000.0         2310      8        2310           1830
# 21610  402101.0         1020      7        1020           1020
# 21611  400000.0         1600      8        1600           1410
# 21612  325000.0         1020      7        1020           1020
#
# [21613 rows x 5 columns]

# %%
g = sns.pairplot(df1_pilih)
